# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Law

# %%
law = pd.read_csv('Law/bar_pass_prediction.csv')
law.pass_bar = law.pass_bar.astype(int)
#histogram of bar pass rate
law.pass_bar.hist()
#save histogram
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Bank

# %%
bank = pd.read_csv('bank/bank-additional-full.csv', sep=';')
bank.y = bank.y.map({'no':0, 'yes':1})
#histogram of bank term deposit
bank.y.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Zindi

# %%
zindi = pd.read_csv('financial-inclusion-in-africa/Train.csv')
zindi.bank_account = zindi.bank_account.map({'No':0, 'Yes':1})
#histogram of bank account
zindi.bank_account.hist()
# Out:
# <AxesSubplot:>
